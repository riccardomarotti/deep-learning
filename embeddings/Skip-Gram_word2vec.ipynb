# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    random = np.random.randint(1, window_size + 1)
    start = idx - random if (idx - random) > 0 else 0
    stop = idx + random
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/ric/virtualenvs/nn/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6455 0.0270 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6123 0.0248 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5070 0.0250 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5980 0.0251 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5011 0.0250 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5242 0.0246 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5434 0.0252 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5269 0.0250 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4995 0.0249 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4447 0.0251 sec/batch
# Nearest to state: uncanonical, afterword, guildford, artifice, vella, automorphism, scheduling, bak,
# Nearest to into: quartered, hashim, bipyramid, itinerarium, mondegreens, approached, contacting, presides,
# Nearest to which: compulsories, ford, brow, random, bech, mulligan, folsom, noncombatants,
# Nearest to some: din, coining, beattie, mischief, correspondents, prophase, punish, violet,
# Nearest to to: jarrett, rady, anna, manoeuvre, wf, two, miner, birthdate,
# Nearest to history: sprockets, appeared, supernaturalism, transmitter, biased, metastasis, prayer, homogenic,
# Nearest to many: masc, illustrate, armaments, tolerated, smeaton, genevan, process, anselm,
# Nearest to their: twitch, overhauled, gaspra, politeness, tunny, label, resiliency, exhorted,
# Nearest to assembly: swampy, banquet, undertones, bankruptcies, semivowel, logik, analytic, sachsen,
# Nearest to discovered: datum, protestors, clokey, sullivan, rietveld, bandung, poachers, kaze,
# Nearest to something: antiproton, edelman, russians, agan, stele, paralleling, crossings, mike,
# Nearest to construction: thoroughgoing, way, musashi, buckhead, hannover, congregationalists, linked, geologists,
# Nearest to pope: assertion, peroxide, edgar, level, ream, shipman, milione, tomb,
# Nearest to applied: toxins, expressions, dra, capricorn, aristocrats, reassessed, plenitude, contest,
# Nearest to freedom: cornish, posit, encroach, democratique, anhydrous, tomcats, syphilis, dominik,
# Nearest to question: nanyang, kursk, encyclopedias, sasha, elie, promoting, familiarly, summarizes,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4929 0.0262 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3801 0.0254 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3570 0.0254 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2502 0.0245 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1731 0.0254 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1422 0.0254 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0754 0.0250 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0738 0.0248 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0081 0.0248 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9664 0.0246 sec/batch
# Nearest to state: town, deaths, scheduling, thomas, like, staged, uncanonical, dominant,
# Nearest to into: quartered, hashim, approached, bipyramid, waged, bad, ray, adding,
# Nearest to which: random, ford, wrote, compulsories, mulligan, trail, accommodation, higher,
# Nearest to some: must, din, coining, punish, beattie, it, to, absolutism,
# Nearest to to: summer, jarrett, anna, some, manoeuvre, wf, birthdate, prolifically,
# Nearest to history: appeared, centre, features, theron, join, prayer, sprockets, extra,
# Nearest to many: masc, process, illustrate, mirror, no, armaments, tolerated, anselm,
# Nearest to their: label, reopened, overhauled, rivalries, speakers, colonialism, twitch, gaspra,
# Nearest to assembly: swampy, logik, analytic, undertones, banquet, answers, semivowel, powers,
# Nearest to discovered: datum, known, sullivan, protestors, though, clokey, compile, cdf,
# Nearest to something: antiproton, paralleling, russians, primary, aging, wealthy, realized, mike,
# Nearest to construction: series, way, thoroughgoing, linked, musashi, hannover, reminiscent, postwar,
# Nearest to pope: level, assertion, rabbis, edgar, propaganda, tomb, peroxide, ream,
# Nearest to applied: toxins, capricorn, actually, expressions, annoying, contest, lengthy, etc,
# Nearest to freedom: posit, cornish, syphilis, andreas, encroach, anhydrous, tomcats, democratique,
# Nearest to question: nanyang, encyclopedias, promoting, kursk, convenience, status, cartridge, promising,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9308 0.0256 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8962 0.0250 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8678 0.0246 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8701 0.0246 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8146 0.0251 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8140 0.0252 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8084 0.0249 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7921 0.0249 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7783 0.0249 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7792 0.0247 sec/batch
# Nearest to state: afterword, scheduling, wembley, automorphism, town, thomas, lent, deaths,
# Nearest to into: quartered, hashim, approached, bipyramid, ray, waged, reith, contacting,
# Nearest to which: random, ford, wrote, compulsories, freeware, mulligan, protocol, brow,
# Nearest to some: correspondents, coining, punish, absolutism, din, must, violet, mischief,
# Nearest to to: anna, miner, jarrett, puts, prolifically, rady, cleansing, summer,
# Nearest to history: appeared, biased, prayer, transmitter, theron, theologians, dances, empty,
# Nearest to many: illustrate, masc, process, armaments, bars, mirror, tolerated, computed,
# Nearest to their: label, gaspra, overhauled, speakers, twitch, politeness, reopened, rivalries,
# Nearest to assembly: swampy, banquet, undertones, answers, umbrella, logik, analytic, powers,
# Nearest to discovered: datum, known, sullivan, though, protestors, narcotics, favour, compile,
# Nearest to something: antiproton, paralleling, primary, wealthy, aging, production, realized, tertiary,
# Nearest to construction: thoroughgoing, linked, geologists, series, hannover, reminiscent, musashi, postwar,
# Nearest to pope: edgar, assertion, rabbis, propaganda, level, tomb, canberra, beckett,
# Nearest to applied: toxins, expressions, capricorn, actually, annoying, aristocrats, contest, reassessed,
# Nearest to freedom: posit, syphilis, publicly, anhydrous, aid, andreas, tomcats, cornish,
# Nearest to question: nanyang, promoting, encyclopedias, kursk, convenience, promising, poorest, sasha,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7939 0.0257 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7448 0.0254 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7409 0.0249 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7001 0.0246 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7092 0.0254 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7029 0.0254 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7062 0.0250 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7380 0.0244 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6889 0.0248 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6727 0.0246 sec/batch
# Nearest to state: afterword, tiberias, occupation, bak, automorphism, staged, granddaughter, carrier,
# Nearest to into: quartered, hashim, approached, bipyramid, reith, contacting, hairpin, waged,
# Nearest to which: random, ford, protocol, folsom, freeware, mulligan, compulsories, wrote,
# Nearest to some: punish, correspondents, must, absolutism, mischief, violet, coining, evasive,
# Nearest to to: cleansing, anna, khanate, miner, rady, jarrett, cohabitation, manoeuvre,
# Nearest to history: appeared, prayer, supernaturalism, taxpayer, biased, champion, transmitter, theologians,
# Nearest to many: illustrate, masc, process, bars, armaments, tolerated, computed, mirror,
# Nearest to their: label, politeness, crossword, reopened, speakers, gaspra, temples, twitch,
# Nearest to assembly: swampy, undertones, powers, banquet, umbrella, polo, logik, answers,
# Nearest to discovered: datum, known, protestors, though, sullivan, narcotics, psychoactive, italia,
# Nearest to something: antiproton, primary, paralleling, tertiary, edelman, realized, wealthy, stele,
# Nearest to construction: thoroughgoing, linked, geologists, hannover, series, goldwyn, congregationalists, reminiscent,
# Nearest to pope: edgar, rabbis, assertion, propaganda, tomb, lindh, son, beckett,
# Nearest to applied: toxins, expressions, actually, capricorn, aristocrats, annoying, etc, plenitude,
# Nearest to freedom: syphilis, posit, cornish, anhydrous, encroach, sophie, tomcats, democratique,
# Nearest to question: nanyang, promoting, kursk, encyclopedias, sasha, convenience, poorest, summarizes,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6594 0.0257 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6961 0.0248 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5990 0.0247 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6416 0.0248 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6228 0.0246 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6352 0.0247 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6015 0.0181 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5204 0.0247 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5263 0.0247 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5208 0.0249 sec/batch
# Nearest to state: bak, afterword, tiberias, vella, uncanonical, occupation, staged, margrave,
# Nearest to into: quartered, hashim, approached, bipyramid, itinerarium, contacting, reith, mondegreens,
# Nearest to which: random, folsom, protocol, compulsories, mulligan, ford, policymakers, freeware,
# Nearest to some: must, absolutism, punish, correspondents, mischief, example, evasive, violet,
# Nearest to to: cleansing, apply, rady, jarrett, miner, khanate, wf, puts,
# Nearest to history: prayer, appeared, supernaturalism, taxpayer, cma, biased, champion, zealanders,
# Nearest to many: illustrate, masc, bars, process, tolerated, armaments, mirror, anselm,
# Nearest to their: label, crossword, politeness, twitch, gaspra, temples, speakers, exhorted,
# Nearest to assembly: swampy, powers, undertones, banquet, lowry, semivowel, logik, bankruptcies,
# Nearest to discovered: known, datum, protestors, though, sullivan, narcotics, soups, psychoactive,
# Nearest to something: antiproton, primary, tertiary, paralleling, edelman, realized, deterministic, stele,
# Nearest to construction: thoroughgoing, linked, geologists, hannover, congregationalists, goldwyn, musashi, vinifera,
# Nearest to pope: edgar, son, rabbis, tomb, assertion, haile, wildcard, milione,
# Nearest to applied: actually, toxins, expressions, capricorn, etc, annoying, aristocrats, defines,
# Nearest to freedom: syphilis, posit, cornish, encroach, democratique, publicly, tomcats, exaltation,
# Nearest to question: nanyang, promoting, kursk, encyclopedias, sasha, mode, familiarly, convenience,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4999 0.0257 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5059 0.0248 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4842 0.0247 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5503 0.0246 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4975 0.0248 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4847 0.0249 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4830 0.0246 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3907 0.0251 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4553 0.0245 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4296 0.0250 sec/batch
# Nearest to state: bak, occupation, afterword, ga, vella, uncanonical, staged, artifice,
# Nearest to into: hashim, quartered, bipyramid, approached, itinerarium, contacting, waged, disloyal,
# Nearest to which: random, folsom, compulsories, protocol, noncombatants, mulligan, freeware, policymakers,
# Nearest to some: absolutism, evasive, must, violet, correspondents, mischief, punish, example,
# Nearest to to: cleansing, rady, jarrett, khanate, apply, gamelan, rectum, puts,
# Nearest to history: prayer, taxpayer, supernaturalism, champion, sprockets, degeneres, swabia, zealanders,
# Nearest to many: illustrate, masc, process, tolerated, bars, armaments, theseus, computed,
# Nearest to their: crossword, temples, label, politeness, twitch, gaspra, speakers, hrvatska,
# Nearest to assembly: swampy, powers, elected, undertones, banquet, bankruptcies, lowry, logik,
# Nearest to discovered: known, datum, protestors, though, soups, clokey, afterburner, sullivan,
# Nearest to something: antiproton, realized, tertiary, edelman, primary, paralleling, plasmodium, jackal,
# Nearest to construction: thoroughgoing, linked, geologists, rampant, hannover, congregationalists, musashi, vinifera,
# Nearest to pope: edgar, son, tomb, rabbis, haile, eminence, wildcard, assertion,
# Nearest to applied: actually, toxins, expressions, capricorn, etc, annoying, defines, plenitude,
# Nearest to freedom: cornish, syphilis, posit, encroach, publicly, heh, tomcats, warrants,
# Nearest to question: nanyang, promoting, mode, kursk, encyclopedias, sasha, familiarly, clock,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4350 0.0254 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4181 0.0250 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4514 0.0250 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4116 0.0247 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3946 0.0247 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4164 0.0248 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3845 0.0250 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3972 0.0251 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3952 0.0249 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3935 0.0248 sec/batch
# Nearest to state: automorphism, bak, artifice, afterword, occupation, executes, vella, ineffective,
# Nearest to into: hashim, quartered, bipyramid, itinerarium, adding, approached, contacting, photometry,
# Nearest to which: random, folsom, compulsories, noncombatants, freeware, protocol, brow, policymakers,
# Nearest to some: must, evasive, absolutism, example, categorizing, mischief, punish, violet,
# Nearest to to: rady, rectum, jarrett, cleansing, apply, gamelan, pitfall, khanate,
# Nearest to history: prayer, supernaturalism, degeneres, empty, taxpayer, khans, champion, grandparents,
# Nearest to many: illustrate, tolerated, masc, process, bars, armaments, theseus, evaluating,
# Nearest to their: crossword, twitch, exhorted, label, hrvatska, temples, lorazepam, gaspra,
# Nearest to assembly: swampy, powers, elected, undertones, seats, legislature, bankruptcies, vote,
# Nearest to discovered: known, datum, protestors, soups, though, psychoactive, afterburner, cdf,
# Nearest to something: antiproton, realized, immanence, edelman, paralleling, plasmodium, deterministic, dualities,
# Nearest to construction: thoroughgoing, linked, geologists, hannover, rampant, vinifera, congregationalists, musashi,
# Nearest to pope: edgar, son, tomb, rabbis, haile, assertion, eminence, bibliotheke,
# Nearest to applied: actually, expressions, toxins, etc, capricorn, defines, annoying, plenitude,
# Nearest to freedom: syphilis, cornish, norms, posit, encroach, democratique, zimbardo, publicly,
# Nearest to question: promoting, nanyang, encyclopedias, kursk, mode, rifleman, familiarly, publish,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3700 0.0255 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3989 0.0246 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3511 0.0248 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3738 0.0249 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4292 0.0251 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3542 0.0248 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4090 0.0248 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4129 0.0247 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3252 0.0247 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3138 0.0250 sec/batch
# Nearest to state: constitutional, automorphism, artifice, occupation, ineffective, bak, payment, vella,
# Nearest to into: hashim, quartered, bipyramid, disloyal, itinerarium, approached, adding, photometry,
# Nearest to which: folsom, random, noncombatants, freeware, compulsories, subtrees, ford, brow,
# Nearest to some: evasive, must, mischief, example, categorizing, punish, correspondents, absolutism,
# Nearest to to: rady, apply, rectum, cleansing, pathogen, meet, khanate, jarrett,
# Nearest to history: degeneres, prayer, khans, supernaturalism, tlingit, empty, taxpayer, champion,
# Nearest to many: illustrate, theseus, tolerated, masc, process, bars, dismantling, may,
# Nearest to their: crossword, hrvatska, sanatana, label, gaspra, exhorted, temples, twitch,
# Nearest to assembly: powers, elected, swampy, legislature, undertones, seats, bankruptcies, vote,
# Nearest to discovered: known, datum, protestors, soups, psychoactive, bandung, afterburner, fermat,
# Nearest to something: antiproton, realized, immanence, edelman, paralleling, dualities, plasmodium, primary,
# Nearest to construction: thoroughgoing, linked, rampant, geologists, vinifera, hannover, musashi, sadie,
# Nearest to pope: edgar, son, tomb, rabbis, haile, assertion, bibliotheke, eminence,
# Nearest to applied: actually, expressions, toxins, capricorn, etc, defines, plenitude, annoying,
# Nearest to freedom: norms, posit, cornish, publicly, zimbardo, encroach, syphilis, democratique,
# Nearest to question: promoting, nanyang, encyclopedias, mode, crips, status, rifleman, views,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3421 0.0256 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3288 0.0252 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3995 0.0248 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3769 0.0250 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3826 0.0249 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2745 0.0249 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3157 0.0245 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3586 0.0248 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2370 0.0246 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2792 0.0249 sec/batch
# Nearest to state: ineffective, artifice, automorphism, bak, naacp, executes, margrave, vella,
# Nearest to into: hashim, quartered, bipyramid, disloyal, itinerarium, adding, approached, msi,
# Nearest to which: random, noncombatants, folsom, subtrees, freeware, brow, compulsories, ford,
# Nearest to some: example, evasive, mischief, categorizing, must, exhibitionism, absolutism, prepositions,
# Nearest to to: rady, apply, meet, rectum, pitfall, khanate, miner, jarrett,
# Nearest to history: degeneres, khans, tlingit, empty, champion, gotham, prayer, supernaturalism,
# Nearest to many: illustrate, theseus, tolerated, bars, masc, dismantling, evaluating, colloquial,
# Nearest to their: crossword, label, hrvatska, twitch, mock, rivalries, lorazepam, gaspra,
# Nearest to assembly: swampy, elected, powers, legislature, seats, vote, bankruptcies, sachsen,
# Nearest to discovered: known, datum, protestors, soups, afterburner, bandung, psychoactive, rrebro,
# Nearest to something: antiproton, immanence, realized, paralleling, edelman, dualities, jackal, deterministic,
# Nearest to construction: linked, thoroughgoing, geologists, vinifera, rampant, hannover, sadie, congregationalists,
# Nearest to pope: edgar, tomb, son, haile, assertion, rabbis, noailles, bibliotheke,
# Nearest to applied: actually, expressions, toxins, capricorn, defines, etc, clearer, monolithic,
# Nearest to freedom: norms, posit, democratique, syphilis, zimbardo, cornish, encroach, warrants,
# Nearest to question: promoting, nanyang, encyclopedias, radical, views, crips, rifleman, mode,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3077 0.0255 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2832 0.0247 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3208 0.0112 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2537 0.0250 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2569 0.0251 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2321 0.0244 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2391 0.0248 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2270 0.0250 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2231 0.0252 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1757 0.0247 sec/batch
# Nearest to state: constitutional, artifice, naacp, automorphism, margrave, vella, ineffective, hearings,
# Nearest to into: hashim, quartered, disloyal, bipyramid, itinerarium, stems, occultations, sophists,
# Nearest to which: noncombatants, folsom, random, subtrees, compulsories, brow, freeware, accordingly,
# Nearest to some: example, mischief, coining, exhibitionism, pluralized, evasive, categorizing, stress,
# Nearest to to: rady, jarrett, rectum, apply, khanate, meet, pitfall, gamelan,
# Nearest to history: degeneres, empty, khans, tlingit, gotham, grandparents, swabia, champion,
# Nearest to many: illustrate, bars, theseus, process, tolerated, masc, synagogues, prosperous,
# Nearest to their: label, crossword, mock, hrvatska, gaspra, displeased, lorazepam, twitch,
# Nearest to assembly: elected, powers, legislature, swampy, vote, congressional, seats, sachsen,
# Nearest to discovered: known, datum, bandung, soups, afterburner, protestors, rrebro, fermat,
# Nearest to something: antiproton, realized, immanence, paralleling, edelman, jackal, dens, dualities,
# Nearest to construction: linked, thoroughgoing, vinifera, geologists, hannover, brel, retraced, musashi,
# Nearest to pope: son, edgar, tomb, bibliotheke, noailles, haile, assertion, rabbis,
# Nearest to applied: actually, expressions, capricorn, toxins, defines, monolithic, semitic, clearer,
# Nearest to freedom: norms, posit, warrants, aid, zimbardo, encroach, democratique, cornish,
# Nearest to question: promoting, nanyang, encyclopedias, radical, crips, status, unknowable, views,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2379 0.0254 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2496 0.0250 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2297 0.0252 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1491 0.0247 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1812 0.0249 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1608 0.0251 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2020 0.0244 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1878 0.0247 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1899 0.0249 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1645 0.0246 sec/batch
# Nearest to state: automorphism, artifice, naacp, constitutional, vella, executes, subalgebra, ga,
# Nearest to into: hashim, quartered, bipyramid, disloyal, itinerarium, adding, contacting, stems,
# Nearest to which: random, folsom, noncombatants, subtrees, massless, compulsories, brow, in,
# Nearest to some: coining, example, mischief, must, to, pluralized, absolutism, exhibitionism,
# Nearest to to: rady, apply, meet, puts, gamelan, rectum, jarrett, khanate,
# Nearest to history: empty, degeneres, tlingit, khans, gotham, champion, transmitter, features,
# Nearest to many: illustrate, process, bars, tolerated, theseus, evaluating, masc, prosperous,
# Nearest to their: crossword, label, lorazepam, twitch, gaspra, displeased, hrvatska, disadvantages,
# Nearest to assembly: legislature, elected, powers, swampy, seats, vote, congressional, codebook,
# Nearest to discovered: known, afterburner, soups, bandung, datum, rrebro, fibonacci, protestors,
# Nearest to something: antiproton, realized, immanence, paralleling, dualities, edelman, jackal, avenge,
# Nearest to construction: linked, thoroughgoing, vinifera, bars, retraced, hannover, brel, congregationalists,
# Nearest to pope: tomb, son, assertion, edgar, rabbis, noailles, bibliotheke, bishop,
# Nearest to applied: actually, expressions, defines, capricorn, toxins, monolithic, etc, clearer,
# Nearest to freedom: norms, posit, warrants, aid, syphilis, encroach, zimbardo, democratique,
# Nearest to question: promoting, encyclopedias, radical, nanyang, deference, resurrect, unknowable, views,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1634 0.0258 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2285 0.0250 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1967 0.0247 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1280 0.0246 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1853 0.0249 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1815 0.0250 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2085 0.0249 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1377 0.0249 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1677 0.0247 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2037 0.0248 sec/batch
# Nearest to state: automorphism, artifice, constitutional, vella, naacp, subalgebra, pohnpei, lesbia,
# Nearest to into: hashim, quartered, bipyramid, disloyal, itinerarium, stems, sophists, adding,
# Nearest to which: folsom, noncombatants, random, in, brow, massless, subtrees, freeware,
# Nearest to some: coining, example, to, must, categorizing, evasive, exhibitionism, mischief,
# Nearest to to: rady, meet, puts, jarrett, apply, some, khanate, gamelan,
# Nearest to history: degeneres, empty, khans, gotham, oxford, uruguay, tlingit, cma,
# Nearest to many: illustrate, theseus, tolerated, prosperous, process, masc, bars, evaluating,
# Nearest to their: label, twitch, gaspra, mock, crossword, lorazepam, displeased, disadvantages,
# Nearest to assembly: elected, legislature, powers, seats, congressional, codebook, vote, swampy,
# Nearest to discovered: known, fibonacci, soups, bandung, datum, afterburner, brightest, rrebro,
# Nearest to something: paralleling, antiproton, immanence, realized, dualities, edelman, resents, avenge,
# Nearest to construction: vinifera, thoroughgoing, linked, brel, musashi, hannover, geologists, congregationalists,
# Nearest to pope: assertion, edgar, noailles, bibliotheke, son, tomb, authenticity, rabbis,
# Nearest to applied: actually, expressions, defines, toxins, clearer, monolithic, plenitude, etc,
# Nearest to freedom: norms, posit, warrants, aid, encroach, syphilis, sheol, commodity,
# Nearest to question: promoting, encyclopedias, radical, nanyang, resurrect, deference, views, unknowable,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1804 0.0256 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1760 0.0248 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1721 0.0250 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1936 0.0249 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1349 0.0247 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1498 0.0246 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1554 0.0247 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1368 0.0246 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1533 0.0251 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2113 0.0250 sec/batch
# Nearest to state: artifice, automorphism, naacp, vella, constitutional, subalgebra, lesbia, pohnpei,
# Nearest to into: hashim, quartered, disloyal, bipyramid, itinerarium, sophists, msi, stems,
# Nearest to which: noncombatants, folsom, random, brow, freeware, in, massless, subtrees,
# Nearest to some: mischief, coining, saviour, absolutism, to, example, rubenstein, evasive,
# Nearest to to: rady, meet, counterrevolutionary, khanate, puts, populace, cordially, cleansing,
# Nearest to history: gotham, degeneres, oxford, empty, khans, durham, swabia, uruguay,
# Nearest to many: illustrate, theseus, synagogues, masc, tolerated, process, prosperous, bars,
# Nearest to their: label, crossword, lorazepam, mock, tenochtitlan, speakers, turnovers, displeased,
# Nearest to assembly: legislature, elected, powers, seats, legislate, codebook, swampy, vote,
# Nearest to discovered: known, fibonacci, bandung, hives, datum, fermat, rrebro, protestors,
# Nearest to something: paralleling, antiproton, realized, immanence, dualities, resents, edelman, dens,
# Nearest to construction: vinifera, thoroughgoing, linked, brel, hannover, musashi, series, congregationalists,
# Nearest to pope: noailles, edgar, bibliotheke, assertion, tomb, xvi, rabbis, bishop,
# Nearest to applied: actually, monolithic, expressions, clearer, plenitude, capricorn, toxins, genuineness,
# Nearest to freedom: norms, posit, warrants, biotech, aid, encroach, polite, sees,
# Nearest to question: promoting, encyclopedias, nanyang, deference, radical, resurrect, crips, status,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2064 0.0255 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1330 0.0245 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1523 0.0249 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1698 0.0251 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0616 0.0251 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1140 0.0246 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1433 0.0249 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1303 0.0248 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1558 0.0042 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1376 0.0249 sec/batch
# Nearest to state: naacp, artifice, automorphism, lesbia, vella, subalgebra, constitutional, each,
# Nearest to into: hashim, quartered, disloyal, bipyramid, sophists, itinerarium, occultations, msi,
# Nearest to which: noncombatants, folsom, random, subtrees, massless, in, brow, freeware,
# Nearest to some: coining, example, stress, pluralized, to, mischief, categorizing, exhibitionism,
# Nearest to to: rady, meet, jarrett, apply, khanate, pitfall, some, counterrevolutionary,
# Nearest to history: gotham, empty, faculties, modern, khans, prehistory, degeneres, brugghen,
# Nearest to many: prosperous, illustrate, bars, colloquial, masc, synagogues, theseus, highlight,
# Nearest to their: mock, label, rivalries, turnovers, lorazepam, crossword, mattress, tenochtitlan,
# Nearest to assembly: elected, seats, legislature, powers, legislate, codebook, swampy, vote,
# Nearest to discovered: known, fibonacci, fermat, bandung, brightest, inhaled, rrebro, datum,
# Nearest to something: paralleling, realized, resents, antiproton, immanence, dualities, dens, shocked,
# Nearest to construction: vinifera, hannover, linked, thoroughgoing, brel, bars, musashi, series,
# Nearest to pope: noailles, edgar, assertion, milione, bibliotheke, pius, haile, authenticity,
# Nearest to applied: actually, monolithic, economies, clearer, electric, capricorn, expressions, general,
# Nearest to freedom: norms, posit, biotech, aid, progress, warrants, sees, zimbardo,
# Nearest to question: promoting, encyclopedias, radical, deference, nanyang, resurrect, crips, exterminate,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0873 0.0256 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0872 0.0251 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0948 0.0248 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0353 0.0250 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0698 0.0246 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0306 0.0247 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0973 0.0248 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0815 0.0251 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1192 0.0251 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0537 0.0247 sec/batch
# Nearest to state: artifice, automorphism, subalgebra, each, naacp, lesbia, drier, constitutional,
# Nearest to into: hashim, quartered, disloyal, bipyramid, sophists, itinerarium, stems, occultations,
# Nearest to which: in, folsom, random, noncombatants, baghdad, subtrees, massless, brow,
# Nearest to some: coining, example, to, saviour, zebulun, exhibitionism, pluralized, mischief,
# Nearest to to: meet, some, pitfall, khanate, counterrevolutionary, jarrett, rady, populace,
# Nearest to history: prehistory, khans, empty, degeneres, gotham, archaeological, faculties, tlingit,
# Nearest to many: illustrate, bars, masc, prosperous, synagogues, process, theseus, tolerated,
# Nearest to their: lorazepam, crossword, rivalries, mattress, mock, turnovers, label, tenochtitlan,
# Nearest to assembly: legislature, seats, elected, codebook, legislate, swampy, powers, semivowel,
# Nearest to discovered: known, fibonacci, bandung, inhaled, rrebro, fermat, brightest, hives,
# Nearest to something: paralleling, realized, antiproton, resents, dualities, jackal, immanence, edelman,
# Nearest to construction: vinifera, brel, boulevards, linked, hannover, bars, thoroughgoing, retraced,
# Nearest to pope: noailles, edgar, bibliotheke, assertion, milione, bishop, son, pius,
# Nearest to applied: actually, economies, monolithic, genuineness, apportionment, electric, toxins, capricorn,
# Nearest to freedom: norms, posit, biotech, aid, warrants, zimbardo, progress, sees,
# Nearest to question: promoting, encyclopedias, deference, radical, nanyang, resurrect, exterminate, crips,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0450 0.0256 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0255 0.0247 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0406 0.0247 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0710 0.0249 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0552 0.0246 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0831 0.0248 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0603 0.0250 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0820 0.0247 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0730 0.0249 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0554 0.0250 sec/batch
# Nearest to state: artifice, subalgebra, automorphism, naacp, huevos, associative, each, thomas,
# Nearest to into: hashim, disloyal, quartered, bipyramid, stems, sophists, contacting, adding,
# Nearest to which: in, random, folsom, massless, noncombatants, subtrees, baghdad, ldap,
# Nearest to some: coining, example, to, exhibitionism, saviour, stress, categorizing, its,
# Nearest to to: puts, meet, some, rady, rectum, require, spokesperson, jarrett,
# Nearest to history: empty, prehistory, faculties, nlcs, gotham, pritzker, degeneres, oxford,
# Nearest to many: illustrate, process, prosperous, colloquial, metallized, bars, non, evaluating,
# Nearest to their: lorazepam, rivalries, mattress, crossword, like, mock, turnovers, disadvantages,
# Nearest to assembly: legislature, seats, elected, codebook, powers, legislate, parliament, vote,
# Nearest to discovered: known, fibonacci, inhaled, rrebro, ldcs, brightest, hives, intensities,
# Nearest to something: paralleling, realized, antiproton, resents, dualities, immanence, plasmodium, oligopoly,
# Nearest to construction: vinifera, brel, linked, boulevards, bars, retraced, hannover, musashi,
# Nearest to pope: noailles, edgar, milione, bibliotheke, textrm, assertion, xii, pius,
# Nearest to applied: actually, electric, clearer, monolithic, genuineness, apportionment, defines, general,
# Nearest to freedom: norms, posit, biotech, sees, aid, warrants, commodity, progress,
# Nearest to question: promoting, encyclopedias, deference, resurrect, radical, nanyang, arius, exterminate,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0450 0.0252 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0827 0.0251 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0937 0.0246 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0884 0.0245 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0848 0.0247 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0494 0.0249 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0753 0.0249 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0565 0.0249 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0680 0.0250 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0806 0.0247 sec/batch
# Nearest to state: naacp, automorphism, subalgebra, artifice, hearings, legislature, each, constitutional,
# Nearest to into: hashim, disloyal, quartered, sophists, stems, contacting, bipyramid, seabird,
# Nearest to which: in, folsom, random, noncombatants, subtrees, freeware, baghdad, brow,
# Nearest to some: coining, saviour, to, example, rady, zebulun, hansard, prepositions,
# Nearest to to: populace, rady, thy, khanate, some, meet, cleansing, puts,
# Nearest to history: prehistory, gotham, modern, nlcs, cultures, khans, brugghen, oxford,
# Nearest to many: prosperous, masc, illustrate, synagogues, colloquial, process, few, bars,
# Nearest to their: rivalries, turnovers, lorazepam, mattress, speakers, crossword, mock, tenochtitlan,
# Nearest to assembly: legislature, elected, seats, powers, legislate, codebook, appoints, parliament,
# Nearest to discovered: known, fibonacci, rrebro, ldcs, fermat, hives, brightest, gummo,
# Nearest to something: paralleling, resents, realized, antiproton, jackal, dualities, marksmanship, giri,
# Nearest to construction: vinifera, boulevards, retraced, brel, hannover, linked, buckhead, series,
# Nearest to pope: noailles, edgar, pius, milione, bishop, assertion, bibliotheke, authenticity,
# Nearest to applied: actually, electric, genuineness, monolithic, clearer, apportionment, economies, toxins,
# Nearest to freedom: biotech, posit, norms, aid, encroach, zimbardo, warrants, progress,
# Nearest to question: promoting, encyclopedias, deference, radical, resurrect, redman, nanyang, tientsin,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0524 0.0253 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0433 0.0251 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0219 0.0249 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0472 0.0246 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0756 0.0251 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1259 0.0251 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0979 0.0247 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0169 0.0246 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0562 0.0245 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0494 0.0247 sec/batch
# Nearest to state: naacp, subalgebra, artifice, each, nebraska, automorphism, hearings, associative,
# Nearest to into: hashim, quartered, disloyal, sophists, stems, bipyramid, contacting, mapped,
# Nearest to which: in, random, noncombatants, folsom, subtrees, freeware, wires, massless,
# Nearest to some: coining, to, example, chime, hansard, names, categorizing, must,
# Nearest to to: meet, some, khanate, populace, apply, puts, spokesperson, merlot,
# Nearest to history: prehistory, gotham, nlcs, faculties, archaeological, oxford, degeneres, brugghen,
# Nearest to many: prosperous, masc, synagogues, illustrate, few, colloquial, theseus, process,
# Nearest to their: turnovers, mattress, like, label, lorazepam, rivalries, speakers, mock,
# Nearest to assembly: legislature, elected, seats, codebook, bankruptcies, legislate, parliament, semivowel,
# Nearest to discovered: known, fibonacci, rrebro, ldcs, inhaled, hives, gummo, fermat,
# Nearest to something: paralleling, antiproton, resents, realized, jackal, dualities, marksmanship, tertiary,
# Nearest to construction: vinifera, boulevards, retraced, hannover, brel, linked, series, interesting,
# Nearest to pope: noailles, edgar, pius, milione, irene, xii, textrm, bibliotheke,
# Nearest to applied: actually, electric, monolithic, genuineness, polarity, clearer, apportionment, economies,
# Nearest to freedom: posit, biotech, norms, sees, encroach, varying, commodity, warrants,
# Nearest to question: promoting, encyclopedias, deference, redman, propanol, resurrect, radical, bartender,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9830 0.0254 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0156 0.0249 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0001 0.0247 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0323 0.0247 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0692 0.0248 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0541 0.0221 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9904 0.0247 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9880 0.0245 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0180 0.0246 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9489 0.0250 sec/batch
# Nearest to state: naacp, nebraska, subalgebra, artifice, each, missouri, hearings, associative,
# Nearest to into: disloyal, hashim, quartered, sophists, shootout, stems, mapped, bipyramid,
# Nearest to which: in, folsom, baghdad, noncombatants, brow, random, massless, tuileries,
# Nearest to some: coining, example, chime, names, as, to, rady, hansard,
# Nearest to to: meet, thy, populace, khanate, rectum, tedium, pathogen, puts,
# Nearest to history: prehistory, nlcs, gotham, archaeological, cultures, faculties, clinics, pritzker,
# Nearest to many: few, illustrate, synagogues, masc, prosperous, process, bars, colloquial,
# Nearest to their: turnovers, mattress, rivalries, like, lorazepam, tenochtitlan, crossword, label,
# Nearest to assembly: seats, codebook, semivowel, elected, legislature, bankruptcies, legislate, consists,
# Nearest to discovered: known, fibonacci, ldcs, brightest, rrebro, inhaled, lush, adversus,
# Nearest to something: paralleling, resents, realized, antiproton, marksmanship, jackal, giri, shocked,
# Nearest to construction: vinifera, boulevards, retraced, brel, hannover, series, interesting, musashi,
# Nearest to pope: noailles, pius, edgar, milione, interdict, xii, bishop, antipope,
# Nearest to applied: actually, electric, monolithic, genuineness, polarity, clearer, apportionment, cushion,
# Nearest to freedom: posit, sees, biotech, norms, encroach, zimbardo, progress, varying,
# Nearest to question: promoting, encyclopedias, deference, propanol, resurrect, radical, redman, arius,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0096 0.0257 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9438 0.0250 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9915 0.0247 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0246 0.0247 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0210 0.0247 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0023 0.0248 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9210 0.0250 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9303 0.0250 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9282 0.0251 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9893 0.0250 sec/batch
# Nearest to state: naacp, subalgebra, artifice, nebraska, missouri, hearings, disproving, automorphism,
# Nearest to into: disloyal, hashim, quartered, stems, sophists, bipyramid, shootout, contacting,
# Nearest to which: in, massless, baghdad, folsom, wires, random, nontrivial, freeware,
# Nearest to some: coining, to, names, chime, example, susceptibility, exhibitionism, zebulun,
# Nearest to to: meet, be, some, pleated, khanate, puts, pathogen, spokesperson,
# Nearest to history: nlcs, prehistory, cyclopedia, clinics, archaeological, transmitter, pritzker, external,
# Nearest to many: few, masc, synagogues, prosperous, bars, non, metallized, illustrate,
# Nearest to their: turnovers, lorazepam, rivalries, mattress, tenochtitlan, crossword, oakland, unsettled,
# Nearest to assembly: legislature, elected, seats, codebook, semivowel, legislate, consists, contest,
# Nearest to discovered: known, fibonacci, ldcs, brightest, inhaled, rrebro, fermat, intensities,
# Nearest to something: paralleling, resents, realized, antiproton, jackal, marksmanship, plasmodium, agan,
# Nearest to construction: boulevards, vinifera, retraced, interesting, hannover, bars, buckhead, brel,
# Nearest to pope: noailles, pius, interdict, milione, edgar, deepened, textrm, xii,
# Nearest to applied: electric, actually, polarity, monolithic, clearer, genuineness, defines, apportionment,
# Nearest to freedom: biotech, posit, norms, encroach, sees, zimbardo, progress, libertarian,
# Nearest to question: promoting, encyclopedias, deference, propanol, forall, snegur, arius, resurrect,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9764 0.0257 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0105 0.0250 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9866 0.0247 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0304 0.0249 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0015 0.0249 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9672 0.0250 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0002 0.0250 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0190 0.0248 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9982 0.0248 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0109 0.0249 sec/batch
# Nearest to state: subalgebra, artifice, naacp, automorphism, each, associative, disproving, missouri,
# Nearest to into: quartered, disloyal, hashim, stems, shootout, sophists, mapped, contacting,
# Nearest to which: in, massless, folsom, random, wires, freeware, nontrivial, noncombatants,
# Nearest to some: coining, to, names, example, pka, as, palpable, exhibitionism,
# Nearest to to: some, be, spokesperson, thy, meet, of, continence, it,
# Nearest to history: nlcs, clinics, prehistory, pritzker, tottenham, faculties, transmitter, cyclopedia,
# Nearest to many: few, masc, illustrate, non, synagogues, criticizing, evangelicalism, prosperous,
# Nearest to their: mattress, lorazepam, turnovers, disadvantages, rivalries, like, speakers, crossword,
# Nearest to assembly: legislature, elected, consists, seats, semivowel, codebook, legislate, legislative,
# Nearest to discovered: known, fibonacci, ldcs, adversus, inhaled, datum, brightest, hives,
# Nearest to something: paralleling, realized, resents, antiproton, dualities, ve, marksmanship, immanence,
# Nearest to construction: vinifera, boulevards, retraced, interesting, buckhead, hannover, brel, series,
# Nearest to pope: noailles, pius, xii, edgar, interdict, authenticity, antipope, deepened,
# Nearest to applied: actually, monolithic, electric, clearer, apportionment, polarity, genuineness, defines,
# Nearest to freedom: biotech, posit, encroach, norms, sees, zimbardo, libertarian, warrants,
# Nearest to question: promoting, deference, encyclopedias, propanol, arius, bartender, resurrect, tientsin,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0104 0.0255 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9961 0.0250 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9830 0.0248 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9812 0.0249 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9808 0.0249 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0178 0.0247 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0068 0.0251 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9610 0.0247 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9540 0.0247 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0294 0.0251 sec/batch
# ...
# Nearest to into: shootout, stems, disloyal, the, confluence, mapped, spark, column,
# Nearest to which: in, the, a, for, this, and, is, an,
# Nearest to some: all, as, such, are, to, although, be, even,
# Nearest to to: the, that, and, be, a, an, in, of,
# Nearest to history: references, external, nlcs, of, prehistory, historical, links, portals,
# Nearest to many: also, few, such, non, have, evangelicalism, of, in,
# Nearest to their: for, to, they, like, such, and, common, turnovers,
# Nearest to assembly: captives, parliament, legislature, consists, rulers, unicameral, semivowel, excommunicates,
# Nearest to discovered: fibonacci, adversus, fermat, discoverer, known, were, univision, ldcs,
# Nearest to something: paralleling, tag, isn, dualities, despair, resents, lendl, ve,
# Nearest to construction: retraced, boulevards, breaches, furniture, allgemeine, goldsmiths, vinifera, brel,
# Nearest to pope: deepened, papal, lindh, pius, edgar, antipope, noailles, authenticity,
# Nearest to applied: electric, refer, defines, genuineness, deprogramming, apportionment, badb, clearer,
# Nearest to freedom: encroach, sees, fedayeen, monopsony, oppression, free, politiken, neoconservative,
# Nearest to question: questions, bartender, encyclopedias, arius, promoting, propanol, snegur, forall,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8471 0.0253 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8449 0.0249 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8584 0.0247 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8153 0.0248 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8906 0.0247 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8498 0.0252 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8544 0.0251 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8381 0.0247 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8847 0.0248 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.7922 0.0252 sec/batch
# Nearest to state: artifice, naacp, subalgebra, flac, compromise, nebraska, legislature, automorphism,
# Nearest to into: disloyal, confluence, the, stems, shootout, spark, quartered, hashim,
# Nearest to which: in, the, a, for, this, and, is, an,
# Nearest to some: as, all, although, are, to, such, usually, have,
# Nearest to to: the, be, and, of, in, an, that, also,
# Nearest to history: external, references, historical, of, prehistory, links, see, nlcs,
# Nearest to many: also, such, few, have, non, of, in, although,
# Nearest to their: for, to, they, like, common, such, naturalization, and,
# Nearest to assembly: legislature, captives, parliament, consists, unicameral, rulers, khama, excommunicates,
# Nearest to discovered: adversus, fermat, discoverer, known, fibonacci, ldcs, were, hypomanic,
# Nearest to something: tag, paralleling, lendl, ve, isn, despair, tertiary, marksmanship,
# Nearest to construction: retraced, allgemeine, boulevards, aqueducts, furniture, breaches, phidias, goldsmiths,
# Nearest to pope: deepened, pius, papal, authenticity, antipope, sozomen, noailles, edgar,
# Nearest to applied: refer, genuineness, electric, defines, deprogramming, apportionment, repugnant, clearer,
# Nearest to freedom: encroach, free, fedayeen, sees, recipients, politiken, monopsony, combat,
# Nearest to question: bartender, questions, encyclopedias, promoting, snegur, arius, forall, propanol,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8759 0.0258 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8658 0.0249 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8217 0.0250 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8384 0.0248 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8988 0.0251 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8421 0.0247 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9551 0.0247 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9104 0.0251 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9143 0.0248 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7928 0.0246 sec/batch
# Nearest to state: naacp, artifice, subalgebra, nebraska, flac, skirts, wyoming, episcopalians,
# Nearest to into: confluence, disloyal, shootout, the, stems, spark, mapped, interested,
# Nearest to which: in, the, a, for, and, this, an, is,
# Nearest to some: are, all, such, be, although, as, have, to,
# Nearest to to: the, be, and, of, in, an, that, also,
# Nearest to history: external, historical, references, of, prehistory, nlcs, links, defunct,
# Nearest to many: also, such, few, have, non, of, evangelicalism, synagogues,
# Nearest to their: for, such, to, they, like, and, naturalization, also,
# Nearest to assembly: parliament, captives, unicameral, consists, elected, legislature, rulers, excommunicates,
# Nearest to discovered: adversus, fermat, fibonacci, discoverer, known, were, ldcs, datum,
# Nearest to something: tag, paralleling, ve, lendl, tertiary, isn, marksmanship, despair,
# Nearest to construction: boulevards, retraced, allgemeine, breaches, series, furniture, aqueducts, mica,
# Nearest to pope: deepened, pius, papal, antipope, sozomen, edgar, authenticity, lindh,
# Nearest to applied: electric, genuineness, repugnant, refer, defines, deprogramming, clearer, accelerating,
# Nearest to freedom: fedayeen, encroach, combat, recipients, sees, politiken, armed, free,
# Nearest to question: bartender, questions, encyclopedias, arius, promoting, snegur, forall, propanol,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7942 0.0255 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8708 0.0248 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8070 0.0248 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8620 0.0248 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8366 0.0248 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8404 0.0251 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9088 0.0121 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8218 0.0252 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8432 0.0248 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8242 0.0244 sec/batch
# Nearest to state: naacp, artifice, nebraska, subalgebra, skirts, wyoming, flac, missouri,
# Nearest to into: confluence, disloyal, the, shootout, stems, spark, drumlins, to,
# Nearest to which: in, the, a, is, for, and, an, this,
# Nearest to some: as, such, all, are, be, although, also, have,
# Nearest to to: the, be, and, of, in, that, an, as,
# Nearest to history: historical, of, references, external, prehistory, nlcs, links, defunct,
# Nearest to many: also, such, few, non, have, including, evangelicalism, although,
# Nearest to their: for, such, and, like, to, they, common, naturalization,
# Nearest to assembly: parliament, captives, unicameral, consists, semivowel, rulers, judicial, elected,
# Nearest to discovered: discoverer, were, known, fermat, fibonacci, adversus, lalla, woodson,
# Nearest to something: tag, paralleling, ve, lendl, isn, resents, despair, tertiary,
# Nearest to construction: retraced, boulevards, breaches, aqueducts, allgemeine, series, furniture, phidias,
# Nearest to pope: papal, pius, deepened, antipope, noailles, sozomen, piedmont, lindh,
# Nearest to applied: deprogramming, electric, genuineness, badb, refer, repugnant, clearer, defines,
# Nearest to freedom: fedayeen, encroach, recipients, sees, armed, combat, monopsony, politiken,
# Nearest to question: bartender, questions, arius, snegur, encyclopedias, promoting, propanol, forall,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8182 0.0254 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8081 0.0247 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8289 0.0248 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8003 0.0249 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8571 0.0247 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8508 0.0248 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8765 0.0247 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7652 0.0247 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7705 0.0250 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8207 0.0250 sec/batch
# Nearest to state: artifice, naacp, nebraska, subalgebra, skirts, wyoming, flac, portions,
# Nearest to into: disloyal, confluence, stems, shootout, spark, the, breakdown, column,
# Nearest to which: in, the, a, for, is, this, and, an,
# Nearest to some: such, as, are, all, to, be, although, or,
# Nearest to to: the, of, be, and, an, in, that, this,
# Nearest to history: of, references, external, historical, links, the, see, prehistory,
# Nearest to many: also, such, few, of, have, non, in, including,
# Nearest to their: such, for, they, to, and, naturalization, common, like,
# Nearest to assembly: unicameral, parliament, captives, elected, legislature, consists, rulers, semivowel,
# Nearest to discovered: discoverer, known, fibonacci, were, fermat, found, adversus, ldcs,
# Nearest to something: tag, paralleling, ve, isn, tertiary, marksmanship, realized, dualities,
# Nearest to construction: boulevards, breaches, retraced, allgemeine, aqueducts, furniture, goldsmiths, aegon,
# Nearest to pope: papal, deepened, pius, antipope, sozomen, lindh, scribner, piedmont,
# Nearest to applied: electric, refer, deprogramming, badb, defines, genuineness, clearer, ois,
# Nearest to freedom: fedayeen, encroach, recipients, politiken, free, combat, armed, oppression,
# Nearest to question: questions, bartender, encyclopedias, arius, propanol, promoting, snegur, forall,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7653 0.0253 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8304 0.0247 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8789 0.0246 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8043 0.0248 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8279 0.0250 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8801 0.0247 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8696 0.0248 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8336 0.0250 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8107 0.0246 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8637 0.0248 sec/batch
# Nearest to state: artifice, naacp, subalgebra, nebraska, wyoming, skirts, flac, effect,
# Nearest to into: shootout, spark, the, disloyal, stems, confluence, to, in,
# Nearest to which: in, the, a, for, is, and, this, an,
# Nearest to some: such, are, as, all, also, to, be, although,
# Nearest to to: the, and, be, in, of, that, an, a,
# Nearest to history: of, references, external, historical, and, links, see, the,
# Nearest to many: also, such, few, non, have, although, of, including,
# Nearest to their: such, for, to, they, like, common, sometimes, some,
# Nearest to assembly: parliament, unicameral, captives, elected, legislature, semivowel, rulers, consists,
# Nearest to discovered: known, were, discoverer, fibonacci, fermat, adversus, found, univision,
# Nearest to something: paralleling, tag, dualities, tertiary, ve, certainty, realized, isn,
# Nearest to construction: breaches, boulevards, retraced, allgemeine, furniture, series, aqueducts, goldsmiths,
# Nearest to pope: papal, deepened, pius, antipope, sozomen, smarter, scribner, lindh,
# Nearest to applied: refer, deprogramming, defines, badb, electric, clearer, genuineness, ois,
# Nearest to freedom: free, recipients, fedayeen, encroach, monopsony, oppression, sweden, armed,
# Nearest to question: bartender, questions, arius, encyclopedias, propanol, promoting, pes, snegur,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8926 0.0258 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8305 0.0247 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8044 0.0248 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8526 0.0248 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8941 0.0249 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8454 0.0249 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8335 0.0248 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8481 0.0248 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8191 0.0249 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7668 0.0246 sec/batch
# Nearest to state: artifice, naacp, wyoming, nebraska, subalgebra, skirts, flac, maldivians,
# Nearest to into: the, in, disloyal, to, as, stems, spark, of,
# Nearest to which: in, the, a, for, this, and, is, an,
# Nearest to some: as, such, are, be, although, to, all, have,
# Nearest to to: the, of, in, and, be, that, this, an,
# Nearest to history: of, references, historical, external, links, see, prehistory, defunct,
# Nearest to many: also, such, few, of, have, although, non, are,
# Nearest to their: such, for, to, common, they, sometimes, like, naturalization,
# Nearest to assembly: parliament, captives, unicameral, excommunicates, elected, legislature, rulers, semivowel,
# Nearest to discovered: discoverer, known, fermat, were, fibonacci, adversus, cometary, lalla,
# Nearest to something: tag, paralleling, ve, isn, tertiary, dualities, certainty, resents,
# Nearest to construction: boulevards, breaches, retraced, aqueducts, mica, allgemeine, phidias, maglev,
# Nearest to pope: papal, deepened, sozomen, antipope, pius, scribner, encyclical, noailles,
# Nearest to applied: refer, deprogramming, clearer, ois, defines, electric, badb, genuineness,
# Nearest to freedom: encroach, fedayeen, recipients, sweden, armed, free, oppression, politiken,
# Nearest to question: questions, bartender, propanol, snegur, encyclopedias, arius, promoting, forall,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8624 0.0254 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8064 0.0250 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9008 0.0248 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9210 0.0248 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8713 0.0247 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8432 0.0252 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7997 0.0248 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7961 0.0248 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7460 0.0250 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8403 0.0251 sec/batch
# Nearest to state: artifice, naacp, wyoming, subalgebra, skirts, nebraska, portions, sotho,
# Nearest to into: the, disloyal, confluence, in, of, shootout, as, stems,
# Nearest to which: in, the, a, for, and, is, this, an,
# Nearest to some: as, such, be, are, also, all, even, although,
# Nearest to to: the, and, of, an, be, a, that, in,
# Nearest to history: of, historical, external, references, links, see, defunct, nlcs,
# Nearest to many: also, such, few, including, non, have, of, are,
# Nearest to their: such, they, like, for, common, performing, to, and,
# Nearest to assembly: unicameral, captives, parliament, elected, judicial, excommunicates, majlis, vote,
# Nearest to discovered: discoverer, were, fibonacci, fermat, known, adversus, lalla, abjuration,
# Nearest to something: paralleling, tag, isn, ve, tertiary, certainty, mediums, dualities,
# Nearest to construction: boulevards, breaches, retraced, aqueducts, mica, phidias, furniture, allgemeine,
# Nearest to pope: papal, antipope, pius, deepened, sozomen, westley, scribner, noailles,
# Nearest to applied: deprogramming, refer, defines, badb, clearer, repugnant, dhimmi, ois,
# Nearest to freedom: fedayeen, recipients, encroach, sweden, oppression, politiken, armed, sees,
# Nearest to question: questions, bartender, encyclopedias, propanol, snegur, arius, promoting, contemptuous,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8560 0.0256 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8208 0.0248 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
